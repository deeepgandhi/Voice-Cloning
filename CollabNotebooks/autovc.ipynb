# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls
# Out:
# bin					   etc	  opt	 sys
# boot					   home   proc	 tensorflow-1.15.2
# content					   lib	  root	 tmp
# datalab					   lib32  run	 tools
# dev					   lib64  sbin	 usr
# dlib-19.18.0-cp27-cp27mu-linux_x86_64.whl  media  srv	 var
# dlib-19.18.0-cp36-cp36m-linux_x86_64.whl   mnt	  swift

# %%
# !ls
# Out:
# autovc_refactor  Neural-Voice-Cloning-With-Few-Samples	tacotron2
# gantts		 Real-Time-Voice-Cloning
# loop		 StarGAN-Voice-Conversion

# %%
cd autovc_refactor/
# Out:
# /content/gdrive/My Drive/Voice_Cloning/autovc_refactor

# %%
# !python3 make_metadata.py
# Out:
# Found directory: ./spmel
# Processing speaker: p225
# Processing speaker: p226
# Processing speaker: p227
# Processing speaker: p228

# %%
# !python3 main.py
# Out:
# Elapsed [0:37:25], Iteration [13700/1000000], G/loss_id: 0.0065, G/loss_id_psnt: 0.0063, G/loss_cd: 0.0012
# Elapsed [0:37:26], Iteration [13710/1000000], G/loss_id: 0.0051, G/loss_id_psnt: 0.0049, G/loss_cd: 0.0010
# Elapsed [0:37:28], Iteration [13720/1000000], G/loss_id: 0.0069, G/loss_id_psnt: 0.0065, G/loss_cd: 0.0012
# Traceback (most recent call last):
#   File "main.py", line 46, in <module>
#     main(config)
#   File "main.py", line 20, in main
#     solver.train()
#   File "/content/gdrive/My Drive/Voice_Cloning/autovc_refactor/solver_encoder.py", line 106, in train
#     loss['G/loss_id'] = g_loss_id.item()
# KeyboardInterrupt

# %%
cd ..
# Out:
# /
