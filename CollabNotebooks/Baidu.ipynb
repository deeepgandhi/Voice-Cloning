# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd gdrive/My Drive/Voice_Cloning
# Out:
# /content/gdrive/My Drive/Voice_Cloning

# %%
# !git clone https://github.com/SforAiDl/Neural-Voice-Cloning-With-Few-Samples
# Out:
# Cloning into 'Neural-Voice-Cloning-With-Few-Samples'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 428 (delta 5), reused 6 (delta 2), pack-reused 413
# Receiving objects: 100% (428/428), 43.33 MiB | 15.30 MiB/s, done.
# Resolving deltas: 100% (128/128), done.
# Checking out files: 100% (79/79), done.

# %%
cd Neural-Voice-Cloning-With-Few-Samples/
# Out:
# /content/gdrive/My Drive/Voice_Cloning/Neural-Voice-Cloning-With-Few-Samples

# %%
# !ls
# Out:
# checkpoints    LICENSE	  speaker_adaptatation-libri.py  train_whole.py
# Cloning_Audio  Modules	  speaker_adaptation.py		 utils.py
# dv3	       README.md  train_dv3.py
# Encoder.py     setup.py   train_encoder.py
